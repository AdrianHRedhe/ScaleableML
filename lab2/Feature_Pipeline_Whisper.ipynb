# %%
# !pip install datasets>=2.6.1
# !pip install git+https://github.com/huggingface/transformers
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-2cd3try0
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-2cd3try0
#   Resolved https://github.com/huggingface/transformers to commit 2098d343cc4b4b9d2aea84b3cf1eb5a1e610deff
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.0.dev0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.0.dev0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.0.dev0) (2023.7.22)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.36.0.dev0-py3-none-any.whl size=8048976 sha256=8fec4c51cfde5a5e55e97dec76267b2b3934abbe2206a3e1fa3215cb560874c3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v6ghqxpp/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed transformers-4.36.0.dev0

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset, DatasetDict

common_voice = DatasetDict()

common_voice["train"] = load_dataset("mozilla-foundation/common_voice_11_0", "sv-SE", split="train+validation", use_auth_token=True)
common_voice["test"] = load_dataset("mozilla-foundation/common_voice_11_0", "sv-SE", split="test", use_auth_token=True)

print(common_voice)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:2088: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=<use_auth_token>' instead.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/8.13k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/14.4k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/60.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.2k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/197M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/139M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/152M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/153M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.6M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.71M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.13M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/312k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Reading metadata...: 1618it [00:00, 14415.93it/s]
# Reading metadata...: 3253it [00:00, 14305.48it/s]
# Reading metadata...: 5133it [00:00, 16011.21it/s]
# Reading metadata...: 7308it [00:00, 15460.27it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Reading metadata...: 5052it [00:00, 39143.27it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Reading metadata...: 5069it [00:00, 25110.55it/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 5699it [00:00, 57757.06it/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 1346it [00:00, 60675.30it/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:2088: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=<use_auth_token>' instead.
#   warnings.warn(
# DatasetDict({
#     train: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 12360
#     })
#     test: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 5069
#     })
# })

# %%
common_voice = common_voice.remove_columns(["accent", "age", "client_id", "down_votes", "gender", "locale", "path", "segment", "up_votes"])

print(common_voice)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 12360
#     })
#     test: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 5069
#     })
# })

# %%
from transformers import WhisperFeatureExtractor

feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-small")
# Out:
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]

# %%
from transformers import WhisperTokenizer

tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small", language="Swedish", task="transcribe")
# Out:
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]

# %%
from transformers import WhisperProcessor

processor = WhisperProcessor.from_pretrained("openai/whisper-small", language="Swedish", task="transcribe")

# %%
print(common_voice["train"][0])
# Out:
# {'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/fe105c40c3a67b7d8c71daeb2d683155832e68cec9b269cd2ee02925b3cee65c/sv-SE_train_0/common_voice_sv-SE_20466896.mp3', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 48000}, 'sentence': 'Du ser ut att ha gjort det här hela livet.'}

# %%
from datasets import Audio

common_voice = common_voice.cast_column("audio", Audio(sampling_rate=16000))

# %%
print(common_voice["train"][0])
# Out:
# {'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/fe105c40c3a67b7d8c71daeb2d683155832e68cec9b269cd2ee02925b3cee65c/sv-SE_train_0/common_voice_sv-SE_20466896.mp3', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 16000}, 'sentence': 'Du ser ut att ha gjort det här hela livet.'}

# %%
def prepare_dataset(batch):
    # load and resample audio data from 48 to 16kHz
    audio = batch["audio"]

    # compute log-Mel input features from input audio array
    batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # encode target text to label ids
    batch["labels"] = tokenizer(batch["sentence"]).input_ids
    return batch

# %%
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
common_voice = common_voice.map(prepare_dataset, remove_columns=common_voice.column_names["train"], num_proc=2)
# Out:
# Map (num_proc=2):   0%|          | 0/12360 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/5069 [00:00<?, ? examples/s]

# %%
common_voice.save_to_disk('/content/drive/My Drive/common_voice')
# Out:
# Saving the dataset (0/24 shards):   0%|          | 0/12360 [00:00<?, ? examples/s]
# Saving the dataset (0/10 shards):   0%|          | 0/5069 [00:00<?, ? examples/s]
